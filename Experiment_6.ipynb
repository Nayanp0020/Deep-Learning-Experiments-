# %%
#Reuters Dataset – Multiclass Classification (DNN)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import reuters
from tensorflow.keras.utils import to_categorical
import numpy as np

# %%
# Load dataset
num_words = 10000

(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=num_words)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#Vectorize data
def vectorize(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, seq in enumerate(sequences):
        results[i, seq] = 1
    return results

x_train = vectorize(x_train)
x_test = vectorize(x_test)

# %%
#One-hot labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
#Build model
model = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(10000,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(46, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compile
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Train
model.fit(x_train, y_train, epochs=5, batch_size=512, validation_split=0.2)
# Out:
# Epoch 1/5
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.4836 - loss: 3.1135 - val_accuracy: 0.5620 - val_loss: 2.2639
# Epoch 2/5
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.6398 - loss: 1.8019 - val_accuracy: 0.6939 - val_loss: 1.4987
# Epoch 3/5
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.7447 - loss: 1.2034 - val_accuracy: 0.7279 - val_loss: 1.2176
# Epoch 4/5
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7997 - loss: 0.8868 - val_accuracy: 0.7602 - val_loss: 1.0734
# Epoch 5/5
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.8582 - loss: 0.6708 - val_accuracy: 0.7780 - val_loss: 0.9950

# %%
# Evaluate
model.evaluate(x_test, y_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7725 - loss: 1.0366
# [1.0366311073303223, 0.7724844217300415]
