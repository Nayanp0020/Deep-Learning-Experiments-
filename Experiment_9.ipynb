# %%
#Temperature Forecasting using RNN (LSTM)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %%
#Create sample time-series data
def create_data(n=1000):
    x = np.sin(np.arange(n) * 0.01)
    return x

data = create_data()

# %%
#Prepare sequences
seq_length = 20

X, y = [], []
for i in range(len(data)-seq_length):
    X.append(data[i:i+seq_length])
    y.append(data[i+seq_length])

X = np.array(X)
y = np.array(y)

X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
#Build LSTM
model = tf.keras.Sequential([
    layers.LSTM(50, return_sequences=False),
    layers.Dense(1)
])

# %%
#Compile
model.compile(optimizer='adam', loss='mse')

# %%
#Train
model.fit(X, y, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1091
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014
# Epoch 8/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 9/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3490e-04
# Epoch 10/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3445e-04
